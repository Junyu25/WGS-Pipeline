# %%
from Bio import SearchIO

# %%
qresults = SearchIO.parse("/mnt/d/Lab/Bile-Acid/result/blastp/test.xml", "blast-xml")

# %%
qresults
# Out:
# <generator object parse at 0x7f5ed41593c0>

# %%
for qresult in qresults:
    print("Search %s has %i hits" % (qresult.id, len(qresult)))
# Out:
# Search NZ_DS499569.1_1 has 0 hits
# Search NZ_DS499569.1_2 has 0 hits
# Search NZ_DS499569.1_3 has 0 hits
# Search NZ_DS499569.1_4 has 0 hits
# Search NZ_DS499569.1_5 has 0 hits
# Search NZ_DS499569.1_6 has 0 hits
# Search NZ_DS499569.1_7 has 0 hits
# Search NZ_DS499569.1_8 has 0 hits
# Search NZ_DS499569.1_9 has 1 hits
# Search NZ_DS499569.1_10 has 0 hits
# Search NZ_DS499569.1_11 has 0 hits
# Search NZ_DS499569.1_12 has 0 hits
# Search NZ_DS499569.1_13 has 0 hits
# Search NZ_DS499569.1_14 has 0 hits
# Search NZ_DS499569.1_15 has 0 hits
# Search NZ_DS499569.1_16 has 0 hits
# Search NZ_DS499569.1_17 has 0 hits
# Search NZ_DS499569.1_18 has 0 hits
# Search NZ_DS499569.1_19 has 0 hits
# Search NZ_DS499569.1_20 has 0 hits
# Search NZ_DS499569.1_21 has 0 hits
# Search NZ_DS499569.1_22 has 0 hits
# Search NZ_DS499569.1_23 has 0 hits
# Search NZ_DS499569.1_24 has 0 hits
# Search NZ_DS499569.1_25 has 0 hits
# Search NZ_DS499569.1_26 has 0 hits
# Search NZ_DS499569.1_27 has 0 hits
# ...

# %%
print(qresults)
# Out:
# <generator object parse at 0x7fcdb27b9270>

# %%
for qresult in qresults:
    print(qresult.hit)
    if qresult.hits == 0:
        print(qresult)

# %%
qresults = SearchIO.parse("/mnt/d/Lab/Bile-Acid/result/blastp/test.tsv", "blast-tab")

# %%
qresults
# Out:
# <generator object parse at 0x7f5ed41a8ac0>

# %%
print(qresults)
# Out:
# <generator object parse at 0x7f5ed41a8ac0>

# %%
for qresult in qresults:
    print("Search %s has %i hits" % (qresult.id, len(qresult)))
# Out:
# Search NZ_DS499569.1_9 has 1 hits
# Search NZ_DS499569.1_71 has 1 hits
# Search NZ_DS499559.1_194 has 1 hits

# %%
for qresult in qresults:
    print(qresult.id)

# %%
qresult
# Out:
# QueryResult(id='NZ_DS499559.1_194', 1 hits)

# %%
qresult.id
# Out:
# 'NZ_DS499559.1_194'

# %%
qresult[0]
# Out:
# Hit(id='BSH_R5XNS0_9CLOT/2-316', query_id='NZ_DS499559.1_194', 1 hsps)

# %%
# ?qresult
# Out:
# Type:           QueryResult
# String form:
# Program: <unknown program> (<unknown version>)
#            Query: NZ_DS499559.1_194
#            <unknown descr <...> -----------------------------
#            0      1  BSH_R5XNS0_9CLOT/2-316  <unknown description>
# Length:         1
# File:           ~/miniconda3/envs/Bio/lib/python3.8/site-packages/Bio/SearchIO/_model/query.py
# Docstring:
# Class representing search results from a single query.
#
# QueryResult is the container object that stores all search hits from a
# single search query. It is the top-level object returned by SearchIO's two
# main functions, ``read`` and ``parse``. Depending on the search results and
# search output format, a QueryResult object will contain zero or more Hit
# objects (see Hit).
#
# You can take a quick look at a QueryResult's contents and attributes by
# invoking ``print`` on it::
#
#     >>> from Bio import SearchIO
#     >>> qresult = next(SearchIO.parse('Blast/mirna.xml', 'blast-xml'))
# ...

# %%
qresult[0].hsps
# Out:
# [HSP(hit_id='BSH_R5XNS0_9CLOT/2-316', query_id='NZ_DS499559.1_194', 1 fragments)]

# %%
# ?qresult[0].hsps
# Out:
# Object `qresult[0].hsps` not found.
